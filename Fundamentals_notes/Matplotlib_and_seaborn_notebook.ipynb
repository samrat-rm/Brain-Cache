# %% [markdown]
# <a href="https://colab.research.google.com/github/samrat-rm/Brain-Cache/blob/main/Matplotlib_and_seaborn_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib
#
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. It is useful for those working with Python and NumPy.
#
# The most used module of Matplotib is Pyplot which provides an interface like MATLAB but instead, it uses Python and it is open source.
#
# Each pyplot function makes some change to a figure: e.g., creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc.
#
# Matplotlib’s charts are made up of two main components:
#
# The axes: the lines that delimit the area of the chart
# The figure: where we draw the axes, titles and elements that come out of the area of the axes.

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Define the path to your image file
image_path = '/content/matplotlib_anatomy.png'

# Open the image using Pillow
try:
    img = Image.open(image_path)
    print(f"Successfully loaded image: {image_path}")

    # Display the image using Matplotlib
    plt.imshow(img)
    plt.axis('off') # Hide axes ticks and labels
    plt.title('Image from Colab Files')
    plt.show()
except FileNotFoundError:
    print(f"Error: Image file not found at {image_path}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Error: Image file not found at /content/matplotlib_anatomy.png

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading Dataset

# %%
data = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/Standard_Metropolitan_Areas_Data-data.csv")
data.head()
# Out:
#    land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0       1384          78.1            12.3       25627          69678
# 1       3719          43.9             9.4       13326          43292
# 2       3553          37.4            10.7        9724          33731
# 3       3916          29.9             8.8        6402          24167
# 4       2480          31.5            10.5        8502          16751
#
#    graduates  work_force  income  region  crime_rate
# 0       50.1      4083.9   72100       1       75.55
# 1       53.9      3305.9   54542       2       56.03
# 2       50.6      2066.3   33216       1       41.32
# 3       52.2      1966.7   32906       2       67.38
# 4       66.1      1514.5   26573       4       80.19

# %%
data.ndim , data.shape
# Out:
# (2, (99, 10))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   land_area       99 non-null     int64
#  1   percent_city    99 non-null     float64
#  2   percent_senior  99 non-null     float64
#  3   physicians      99 non-null     int64
#  4   hospital_beds   99 non-null     int64
#  5   graduates       99 non-null     float64
#  6   work_force      99 non-null     float64
#  7   income          99 non-null     int64
#  8   region          99 non-null     int64
#  9   crime_rate      99 non-null     float64
# dtypes: float64(5), int64(5)
# memory usage: 7.9 KB

# %%
data.describe()
# Out:
#           land_area  percent_city  percent_senior    physicians  \
# count     99.000000     99.000000       99.000000     99.000000
# mean    2615.727273     42.518182        9.781818   1828.333333
# std     3045.826210     17.348277        2.524547   3192.199763
# min       47.000000     13.400000        3.900000    140.000000
# 25%     1408.000000     30.100000        8.350000    459.000000
# 50%     1951.000000     39.500000        9.700000    774.000000
# 75%     2890.500000     52.600000       10.750000   1911.500000
# max    27293.000000    100.000000       21.800000  25627.000000
#
#        hospital_beds  graduates   work_force        income     region  \
# count      99.000000  99.000000    99.000000     99.000000  99.000000
# mean     6345.868687  54.463636   449.366667   6762.505051   2.494949
# std      9136.202716   7.773286   610.990885  10393.349660   1.013921
# min       481.000000  30.300000    66.900000    769.000000   1.000000
# ...

# %% [markdown]
# # Scatter Plot

# %%
plt.scatter(data.crime_rate,data.graduates)
plt.show()

# %% [markdown]
# Both structures that store the values `data.crime_rate` and `data.graduates` must have the same size, so that the obijective relationship is maintained between each point of the independent variable $x$ with its corresponding one in the dependent variable $y$.

# %%
plt.scatter(data.crime_rate,data.graduates)

plt.title("Plot of Crime rate Vs Graduates")
plt.xlabel("Crime rate")
plt.ylabel("Graduates")
plt.show()

# %% [markdown]
# # Line Plot

# %%
plt.plot(data.work_force,data.income)
plt.xlabel("Work Force")
plt.ylabel("Income")
plt.title("Plot of Work Force Vs Income")
plt.show()

# %% [markdown]
# Because it is a line chart, `matplotlib` automatically draws a line to connect each pair of consecutive points that represent Cartesian coordinates on the graph. We can also make a graph with a single input argument:

# %%
plt.plot([1, 2, 3, 4]) # 1 argument
plt.show()

# %% [markdown]
# You may be wondering why the x-axis ranges from 0-3 and the y-axis from 1-4. If you provide a single list or array of $n$ elements to the `.plot()` function, `matplotlib` will assume it is a sequence of $y$ values, and **automatically generates the $x$ values for you** as a range of $n$ elements starting from 0. Since python ranges start with 0, the default $x$ vector has the same length as $y$. Hence the $x$ data will be [0,1,2,3].

# %% [markdown]
# #### Changing the size of the plot

# %%
plt.figure(figsize=(12,5))

plt.plot(data.work_force,data.income)
plt.xlabel("Work Force")
plt.ylabel("Income")
plt.title("Plot of Work Force Vs Income")
plt.show()

# %% [markdown]
# #### Formatting the style of plot

# %%
plt.plot(data.work_force,data.income,linestyle="--",marker="o",color='r')
plt.xlabel("Work Force")
plt.ylabel("Income")
plt.title("Plot of Work Force Vs Income")
plt.show()

# %% [markdown]
# #### A shortcut for the above
#
# For every x, y pair of arguments, there is an optional third argument which is the format string that indicates the color and line type of the plot. The letters and symbols of the format string are from MATLAB, and you concatenate a color string with a line style string. The default format string is 'b-', which is a solid blue line.

# %%
plt.plot(data.work_force,data.income,'--ro') # -- linestyle r colour o marker
plt.xlabel("Work Force")
plt.ylabel("Income")
plt.title("Plot of Work Force Vs Income")
plt.show()

# %% [markdown]
# We can plot scatter plot as well using `plot()`

# %%
plt.plot(data.work_force,data.income,'ro') # no linestyle
plt.xlabel("Work Force")
plt.ylabel("Income")
plt.title("Plot of Work Force Vs Income")
plt.show()

# %%
plt.plot(data.work_force,data.income,'bx') # no linestyle b color x marker
plt.xlabel("Work Force")
plt.ylabel("Income")
plt.title("Plot of Work Force Vs Income")
# plt.show() --> no plt.show() beause the notebook has inbuilt functions but we need how() for normal py script
# Out:
# Text(0.5, 1.0, 'Plot of Work Force Vs Income')

# %% [markdown]
# There are plenty of other options. You can try the following:
#
# ```
# plt.plot(x.work_force, x.income, "go") # green circles
# plt.plot(x.work_force, x.income, "g^") # green traingles
# plt.plot(x.work_force, x.income, "ro") # red circles
# plt.plot(x.work_force, x.income, "rx") # red x symbol
# plt.plot(x.work_force, x.income, "b^") # red ^ symbol
# plt.plot(x.work_force, x.income, "go--", linewidth=3) # green circles and dashed lines of width 3.
# ```

# %%
# multiple plot

plt.plot(data.work_force,data.income,"g^")

plt.plot(data.work_force,data.income,"rx")

# %% [markdown]
# In this case the notebook inbuilt plotting function will plot over each other. So, mention `plt.show()` for this cases

# %%
# multiple plot

plt.plot(data.work_force,data.income,"g^")
plt.show()
plt.plot(data.work_force,data.income,"ro")
plt.show()

# %%
plt.plot(data.work_force,data.income,"-g", label="work_force")
plt.plot(data.physicians,data.income,"-r",label="physician")
plt.legend()
plt.show()

# %% [markdown]
# **Note:** `plt.plot(..., label="work_force")` without label argument the `plt.legend()` will be empty

# %% [markdown]
# ## Subplot
#
# The `.subplot()` method is used to add multiple plots in one figure. It takes three arguments:
#
# 1. `nrows`: number of rows in the figure
# 2. `ncols`: number of columns in the figure
# 3. `index`: index of the plot
# Let's see how variables are plotted with different row and column configurations in the figures.

# %%
plt.subplot(1,2,1) # row,col,ind
plt.plot(data.work_force,data.income,"-g")
plt.title("Work Force Vs Income")

plt.subplot(1,2,2)
plt.plot(data.physicians,data.income,"-r")
plt.title("Physician Vs Income")

plt.show()

# %%
# improving the above plot
plt.subplot(1,2,1) # row,col,ind
plt.plot(data.work_force,data.income,"go")
plt.title("Work Force Vs Income")

plt.subplot(1,2,2).label_outer()
plt.plot(data.physicians,data.income,"r^")
plt.title("Physician Vs Income")

plt.suptitle("Income Analysis plots")

plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(data.work_force,data.income,"go")
plt.title("Work Force Vs Income")

plt.subplot(2,1,2)
plt.plot(data.physicians,data.income,"r^")
plt.title("Physician Vs Income")

plt.suptitle("Income Analysis plots")
plt.show()

# %% [markdown]
# `plt.subplot()` and `plt.subplots()` are differnet

# %%
# 4 x 4

fig , ax = plt.subplots(2,2,figsize=(10,10))
ax[0,0].plot(data.work_force,data.income,"go")
ax[0,0].set_title("Work Force Vs Income")
ax[0,1].plot(data.physicians,data.income,"r^")
ax[0,1].set_title("Physician Vs Income")
ax[1,0].plot(data.work_force,data.income,"g^")
ax[1,0].set_title("Work Force Vs Income")
ax[1,1].plot(data.physicians,data.income,"ro")
ax[1,1].set_title("Physician Vs Income")

plt.show()

# %% [markdown]
# # Histogram

# %% [markdown]
# Parameters:
# - x(n,) : this takes either a single array or a sequence of arrays which are not required to be of the same length.
# - bins : If bins is an integer, it defines the number of equal-width bins in the range.
#
#     If bins is a sequence, it defines the bin edges, including the left edge of the first bin and the right edge
#     of the last bin; in this case, bins may be unequally spaced. All but the last (righthand-most) bin is half-
#     open.
#
#     In other words, if bins is:
#
#     [1, 2, 3, 4]
#
#     then the first bin is [1, 2) (including 1, but excluding 2) and the second [2, 3). The last bin, however, is
#     [3, 4], which includes 4.
#
#     If bins is a string, it is one of the binning strategies supported by numpy.histogram_bin_edges: 'auto', 'fd',
#     'doane', 'scott', 'stone', 'rice', 'sturges', or 'sqrt'.
#
#     The default is rcParams["hist.bins"] (default: 10).

# %%
data['percent_senior'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 99 entries, 0 to 98
# Series name: percent_senior
# Non-Null Count  Dtype
# --------------  -----
# 99 non-null     float64
# dtypes: float64(1)
# memory usage: 924.0 bytes

# %%
data["percent_senior"].describe()
# Out:
# count    99.000000
# mean      9.781818
# std       2.524547
# min       3.900000
# 25%       8.350000
# 50%       9.700000
# 75%      10.750000
# max      21.800000
# Name: percent_senior, dtype: float64

# %%
plt.title("Freq of senior citizen in metropolitan area")
plt.xlabel("% of senior citizens")
plt.ylabel("Frequency")
plt.hist(data["percent_senior"])
plt.show()

# %% [markdown]
# # Seaborn

# %% [markdown]
# `Seaborn` is a Python data visualization library based on `Matplotlib`. It provides a high-level interface for creating attractive graphs, and statistical data visualization.
#
# Seaborn has a lot to offer. You can create graphs in one line that would take you multiple tens of lines in `Matplotlib`. Its standard designs are awesome and it also has a nice interface for working with pandas dataframes.
#
# In the following sections we will review how to graph with `seaborn`

# %%
import seaborn as sns

# %%
iris = sns.load_dataset("iris")

iris.sample(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 41            4.5          2.3           1.3          0.3      setosa
# 94            5.6          2.7           4.2          1.3  versicolor
# 113           5.7          2.5           5.0          2.0   virginica
# 30            4.8          3.1           1.6          0.2      setosa
# 97            6.2          2.9           4.3          1.3  versicolor
# 128           6.4          2.8           5.6          2.1   virginica
# 78            6.0          2.9           4.5          1.5  versicolor
# 45            4.8          3.0           1.4          0.3      setosa
# 132           6.4          2.8           5.6          2.2   virginica
# 80            5.5          2.4           3.8          1.1  versicolor

# %%
# Scatter plot
sns.scatterplot(x="sepal_length",y="sepal_width",data=iris)
plt.show()

# %%
sns.swarmplot(x="species",y="petal_length",data=iris)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
iris.select_dtypes(include=["number"])
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
iris.select_dtypes(include=["number"]).corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
# Correlation matrix completely ignores any non-numeric column.
sns.heatmap(iris.select_dtypes(include=['number']).corr(), annot=True)
plt.show()

# %% [markdown]
# - Each square shows the correlation between the variables on each axis.
# - Correlation ranges from -1 to +1.
# - Values closer to zero means there is no linear trend between the two variables.
# - The more close to 1 the correlation is the more positively correlated they are; that is as one increases so does the other.
# - A correlation closer to -1 is similar, but instead of both increasing one variable will decrease as the other increases.

# %%
# Bar chart
plt.bar(data.region,data.crime_rate,color="g")

plt.title("Bar chart")
plt.xlabel("Region")
plt.ylabel("Crime rate")
plt.show()

# %%
# Horizontal Bar chart
plt.barh(data.region,data.crime_rate,color="g")

plt.title("Bar chart")
plt.xlabel("Region")
plt.ylabel("Crime rate")
plt.show()

# %%
divisions = ["A", "B", "C", "D", "E"]
division_avg = [70, 82, 73, 65, 68]
boys_avg = [68, 67, 77, 61, 70]
girls_avg = [72, 97, 69, 69, 66]


# Using the NumPy arange function to generate values for index between 0-4.
# Here,stop is 5, start is 0, and step is 1
index = np.arange(5)
width = 0.30

# %%
# Bar chart with Multiple Quantities

# bar(x_axis , y_axis , bar_width, color, label )
plt.bar(index, division_avg, width, color="green", label="Division Marks")
plt.bar(index+width, boys_avg, width, color="blue", label="Boys Marks")

plt.title("Bar Graph")
plt.xlabel("Divisions")
plt.ylabel("Marks")
plt.legend()
plt.show()

# %%
# stacked bar chart

# same data as above

plt.bar(index, boys_avg, width, color="blue", label="Boys Marks")
plt.bar(index, girls_avg, width, color="red", label="Girls Marks", bottom=boys_avg)
# bottom arg is most important otherwise it will overlap

plt.title("Bar Graph")
plt.xlabel("Divisions")
plt.ylabel("Marks")
plt.legend()
plt.show()

# %%
# pie chart

firms = ["Firm A", "Firm B", "Firm C", "Firm D", "Firm E"]
market_share = [20,25,15,10,20]

plt.pie(market_share, labels=firms)
plt.legend()
plt.show()

# %%
# improve the above graph

# Explode the pie chart to emphasize a certain part or some parts( Firm B in this case)
# It is useful because it makes the highlighted portion more visible.
Explode = [0,0.1,0,0,0]

plt.pie(market_share, explode=Explode, labels=firms, autopct='%1.1f%%', startangle=45)

plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.

plt.legend(title="List of Firms")

plt.show()

# %% [markdown]
# `plt.axis('equal')` tells matplotlib:
#
# “Use the same scale on the x-axis and y-axis.”
#
# Without it, matplotlib may stretch the plot to fit the figure window, turning circles into ovals.

# %% [markdown]
# # Exercises
